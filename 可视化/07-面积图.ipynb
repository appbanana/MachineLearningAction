# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 绘制简单的面积填充图
x = np.random.randn(1000)
x.sort()
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x, y1)
plt.plot(x, y2)
# 填充两条线之间的区域
plt.fill_between(x, y1, y2, color='r', alpha=0.7)
